# %% [markdown]
# # Primer programa en Python
# ## Hola mundo desde Python
# * Nombre: Cynthia Cuñez
# * Fecha: **23-06-2026**
# * Repositorio: <a href="https://github.com/cynthia0206/machine12926nocturno/blob/main/holaMundo.ipynb">Link del repositorio de Github</a>

# %% [markdown]
# Esta seccion es para crear una funcion lambda donde calculo la raiz de un numero

# %%
# Comentario en python salundando desde python 
print("Hola mundo desde Python")
# Out:
# Hola mundo desde Python
